# %%
import util
from collections import namedtuple
# Out:
# Using TensorFlow backend.

# %%
def get_params():
    hps_dict = {
        'train_file' : '/home/ubuntu/data/summary/train/*.csv',
        'validate_file' : '/home/ubuntu/data/summary/validate/*.csv',
        'test_file' : '/home/ubuntu/data/summary/test/*.csv',
        'loss_func':'mae',
        'optimizer':'adam',
        'hidden_dim' : 250,
        'batch_size' : 100,
        'epochs' : 30,
        'model_lstm':True
        'filter_outliers':True,
        'outlier_percentile':99.5
    }
    
    hps = namedtuple("HParams", hps_dict.keys())(**hps_dict)
    return hps

# %%
util.train(get_params())
# Out:
# TRAIN::  (709734, 1, 9) (709734,)
# VALIDATE::  (24485, 1, 9) (24485,)
# Train on 709734 samples, validate on 24485 samples
# Epoch 1/30
#  - 42s - loss: 5619.6385 - val_loss: 5770.2230
# Epoch 2/30
#  - 40s - loss: 5391.2479 - val_loss: 5564.8913
# Epoch 3/30
#  - 41s - loss: 5202.1015 - val_loss: 5394.1341
# Epoch 4/30
#  - 40s - loss: 5042.8874 - val_loss: 5255.4057
# Epoch 5/30
#  - 40s - loss: 4910.6967 - val_loss: 5147.2189
# Epoch 6/30
#  - 41s - loss: 4803.5653 - val_loss: 5065.9602
# Epoch 7/30
#  - 41s - loss: 4719.6724 - val_loss: 5008.5473
# Epoch 8/30
#  - 41s - loss: 4657.0541 - val_loss: 4971.1389
# Epoch 9/30
#  - 41s - loss: 4613.7604 - val_loss: 4950.1284
# Epoch 10/30
#  - 41s - loss: 4587.2619 - val_loss: 4941.1195
# Epoch 11/30
#  - 40s - loss: 4573.3191 - val_loss: 4939.1904
# Epoch 12/30
#  - 40s - loss: 4566.9977 - val_loss: 4940.0706
# Epoch 13/30
#  - 40s - loss: 4564.3839 - val_loss: 4941.4442
# Epoch 14/30
#  - 40s - loss: 4563.2977 - val_loss: 4942.5470
# Epoch 15/30
#  - 40s - loss: 4562.8070 - val_loss: 4943.2691
# Epoch 16/30
#  - 40s - loss: 4562.5619 - val_loss: 4943.7241
# Epoch 17/30
#  - 39s - loss: 4562.4098 - val_loss: 4943.9910
# Epoch 18/30
#  - 39s - loss: 4562.3077 - val_loss: 4944.1542
# Epoch 19/30
#  - 39s - loss: 4562.2303 - val_loss: 4944.2539
# Epoch 20/30
#  - 39s - loss: 4562.1664 - val_loss: 4944.3111
# Epoch 21/30
#  - 39s - loss: 4562.1135 - val_loss: 4944.3456
# Epoch 22/30
#  - 39s - loss: 4562.0677 - val_loss: 4944.3662
# Epoch 23/30
#  - 39s - loss: 4562.0274 - val_loss: 4944.3774
# Epoch 24/30
#  - 39s - loss: 4561.9911 - val_loss: 4944.3819
# Epoch 25/30
#  - 39s - loss: 4561.9586 - val_loss: 4944.3846
# Epoch 26/30
#  - 39s - loss: 4561.9287 - val_loss: 4944.3862
# Epoch 27/30
#  - 39s - loss: 4561.9014 - val_loss: 4944.3864
# Epoch 28/30
#  - 39s - loss: 4561.8769 - val_loss: 4944.3884
# Epoch 29/30
#  - 39s - loss: 4561.8541 - val_loss: 4944.3909
# Epoch 30/30
#  - 39s - loss: 4561.8329 - val_loss: 4944.3917
# TEST::  (20077, 1, 9) (20077,)
# Test RMSE: 10230.544
# Test MAE: 4374.357
# Baseline Normalized MAE: 0.806

# %% [markdown]
# $x_{t+1}$
