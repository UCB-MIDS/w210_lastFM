# %%
import util
from collections import namedtuple


# %matplotlib inline

# %%
def get_params():
    hps_dict = {
        'data_file' : '/home/ubuntu/data/user_profile_cluster.csv',
        'use_spectral_clustering':True,
        'cluster_columns':(0,8),
        'clusters':5,
        'standardize':False,
        'mix_std':False,
        'train_file':'/home/ubuntu/data/summary/train/{0}.csv',
        'test_file':'/home/ubuntu/data/summary/test/{0}.csv',
        'validate_file':'/home/ubuntu/data/summary/validate/{0}.csv',
        'model_dir':'/home/ubuntu/data/models/',
        'loss_func':'mae',
        'optimizer':'adam',
        'hidden_dim' : 250,
        'batch_size' : 400,
        'epochs' : 500,
        'layered':False,
        'layer_dims':150,
        'no_layers':1,
        'model_lstm':True,
        'filter_outliers':False,
        'baseline_mae':4932.859,#4828.088,
        'baseline_mae_std':0.770,
        'dropout':[0.0],
        'verbose_level':2,
        'plot_eval':False
    }
    
    hps = namedtuple("HParams", hps_dict.keys())(**hps_dict)
    return hps

# %%
util.plot_cluster_elbow(get_params())

# %%
util.plot_clusters(get_params())

# %%
util.get_baseline_mae(get_params())
# Out:
# 100%|██████████| 19778/19778 [00:01<00:00, 10826.43it/s]
# Test RMSE: 8266.944
# Test MAE: 4932.859

# %%
util.silhouette_analysis(get_params(),10)
# Out:
# For n_clusters = 2 The average silhouette_score is : 0.349149486885615
# For n_clusters = 3 The average silhouette_score is : 0.349149486885615
# For n_clusters = 4 The average silhouette_score is : 0.34867323348371326
# For n_clusters = 5 The average silhouette_score is : 0.349149486885615
# For n_clusters = 6 The average silhouette_score is : 0.349149486885615
# For n_clusters = 7 The average silhouette_score is : 0.34867323348371326
# For n_clusters = 8 The average silhouette_score is : 0.349149486885615
# For n_clusters = 9 The average silhouette_score is : 0.34867323348371326

# %%
users = [5978, 1797, 4930, 6524]
normalized_mae = [0.46, 1.12, 0.60, 0.74]
sum(x * y for x, y in zip(users, normalized_mae)) / sum(users)
# Out:
# 0.6525705964948776
